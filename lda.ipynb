# %% [markdown]
# #Import libraries

# %%
import pandas as pd
import numpy as np
import spacy
import random

# !pip install -U gensim

from gensim import models
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel
from gensim.test.utils import datapath

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
from matplotlib import gridspec
# %matplotlib inline

# !pip install pyLDAvis

import pyLDAvis
import pyLDAvis.gensim_models
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 2.0 MB/s
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.2
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=31fc2b3c5d1d6ba7efb4733f4255c604193df57ebe1e53ba5963cf9e941ce5aa
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.17 pyLDAvis-3.3.1
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping

# %% [markdown]
# #Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
abstracts = pd.read_csv("/content/drive/MyDrive/TFM/preprocessed_lda.csv",
                        index_col=0)
print(abstracts.shape)
abstracts.head()
# Out:
# (25828, 3)
#                                                 Text       Label  \
# 0  "https://paperswithcode.com/method/multiple-ra...     General
# 1  "https://paperswithcode.com/method/dblock DBlo...     General
# 2  "https://paperswithcode.com/method/gan-tts GAN...  Sequential
# 3  "https://paperswithcode.com/method/conditional...     General
# 4  "https://paperswithcode.com/method/gblock GBlo...     General
#
#                                               Tokens
# 0  ['multipl', 'random', 'window', 'discrimin', '...
# 1  ['dblock', 'dblock', 'dblock', 'residu', 'base...
# 2  ['gan', 'tts', 'gan', 'tts', 'gan', 'tts', 'ge...
# 3  ['condit', 'dblock', 'condit', 'dblock', 'cond...
# 4  ['gblock', 'gblock', 'gblock', 'type', 'residu...

# %% [markdown]
# #Create corpus

# %% [markdown]
# Now that we have our final abstracts we create a dictionary

# %%
abstracts.Tokens = abstracts.Tokens.apply(eval)
diccionario = Dictionary(abstracts.Tokens)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 4856

# %% [markdown]
# Finally, we remove the words that are in less than two abstracts and in more than 80% of them since these will introduce more noise than information into our model. Once these words have been filtered we create the final bag of words.

# %%
#Words that are at least in two abstracts and in no more than 80% of abstracts
diccionario.filter_extremes(no_below=2, no_above = 0.8)
print(f'Número de tokens: {len(diccionario)}')
# Out:
# Número de tokens: 3890

# %%
#Doc to bag of words (here we dont take into account bigrams or trigrams)
corpus = [diccionario.doc2bow(abstract) for abstract in abstracts.Tokens]
print(corpus[20])
print(diccionario[17])
#Word with key 9 appears once, word with key 17 appears 6 times , etc
# Out:
# [(9, 1), (17, 6), (70, 1), (123, 1), (137, 7), (145, 1), (177, 1), (191, 1), (257, 1), (273, 1), (285, 1), (313, 4), (314, 1), (461, 1), (462, 1), (464, 1), (465, 1), (466, 1), (467, 1), (468, 1)]
# block

# %% [markdown]
# #LDA

# %%
#We start with 7 values based on number of labels
lda = LdaModel(corpus=corpus, id2word=diccionario, 
               num_topics=7, random_state=42, 
               chunksize=1000, passes=10, alpha='auto')

# %%
topicos = lda.print_topics(num_words=5, num_topics=20)
for topico in topicos:
    print(topico)
# Out:
# (0, '0.059*"attent" + 0.057*"residu" + 0.049*"map" + 0.030*"layer" + 0.026*"block"')
# (1, '0.026*"convolut" + 0.025*"posit" + 0.024*"network" + 0.020*"imag" + 0.019*"map"')
# (2, '0.043*"network" + 0.031*"convolut" + 0.031*"use" + 0.020*"object" + 0.019*"generat"')
# (3, '0.035*"loss" + 0.019*"imag" + 0.019*"object" + 0.017*"scale" + 0.014*"exampl"')
# (4, '0.043*"model" + 0.037*"transform" + 0.036*"train" + 0.022*"pre" + 0.019*"represent"')
# (5, '0.059*"layer" + 0.045*"block" + 0.032*"residu" + 0.032*"convolut" + 0.028*"use"')
# (6, '0.025*"featur" + 0.017*"normal" + 0.014*"use" + 0.013*"network" + 0.011*"weight"')

# %%
for i in range(1, 5):
    plt.figure()
    plt.imshow(WordCloud(background_color='white', prefer_horizontal=1.0)
               .fit_words(dict(lda.show_topic(i, 20))))
    plt.axis("off")
    plt.title("Tópico " + str(i))
    plt.show()

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, diccionario, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el701404228707364645031790312"></div>
# <script type="text/javascript">
#
# var ldavis_el701404228707364645031790312_data = {"mdsDat": {"x": [-0.2715884047752172, 0.004869731982416426, 0.07349479240708669, 0.13813818427536662, 0.13900963320582158, -0.2209845158916455, 0.13706057879617112], "y": [0.15097749034661032, -0.08516721408707405, -0.14386070764683218, -0.01935993587589363, 0.25569839605914896, -0.11399777765838945, -0.04429025113757007], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [10.244416711601728, 12.86484674978241, 16.498225423275827, 14.34343565367763, 14.429556208300252, 10.311338387641314, 21.30818086572084]}, "tinfo": {"Term": ["residu", "layer", "attent", "block", "loss", "map", "transform", "convolut", "model", "posit", "train", "pre", "incept", "encod", "featur", "function", "bert", "represent", "resnet", "network", "bottleneck", "normal", "languag", "channel", "stack", "exampl", "polici", "mask", "fit", "connect", "fit", "nonlinear", "unreferenc", "under", "recast", "although", "arcfac", "versus", "margin", "nbsp", "swap", "show", "shorter", "lilian", "weng", "angular", "consider", "ontop", "gain", "hope", "fifti", "inter", "cardin", "intra", "infogan", "angl", "shortcut", "curv", "hyperspher", "meaning", "head", "let", "extrem", "ident", "anoth", "stack", "easier", "residu", "attent", "denot", "desir", "map", "softmax", "matric", "recognit", "push", "resnet", "skip", "optim", "block", "connect", "multi", "function", "refer", "learn", "layer", "origin", "mechan", "instead", "type", "network", "use", "modul", "deep", "absolut", "cycl", "graph", "contract", "downsampl", "cyclegan", "unpair", "dqn", "2x2", "frequenc", "trick", "perceptu", "rectifi", "geometr", "meta", "sinusoid", "ai", "hypothes", "sine", "d2l", "wavelength", "biject", "cannot", "necessari", "biomed", "border", "unpad", "relu6", "coordin", "segnet", "domain", "sensit", "doubl", "revers", "consist", "posit", "crop", "net", "path", "chosen", "encod", "yolov4", "expans", "cosin", "relu", "grid", "determinist", "target", "function", "loss", "convolut", "follow", "imag", "network", "map", "embed", "two", "dimens", "translat", "learn", "featur", "use", "linear", "model", "architectur", "object", "number", "layer", "incept", "v2", "yolov2", "aspect", "v4", "increment", "dilat", "audio", "ssd", "yolo9000", "stronger", "v3", "yolov1", "wavenet", "atrous", "stylegan", "otherwis", "tell", "rpns", "handl", "resampl", "predecessor", "character", "guidelin", "deeplabv2", "stuff", "www", "trigger", "newfangl", "batchnorm", "impact", "yolov3", "vgg", "darknet", "rpn", "fast", "match", "box", "region", "anchor", "fulli", "singl", "improv", "better", "faster", "generat", "filter", "real", "network", "detect", "bound", "gan", "propos", "convolut", "object", "use", "architectur", "cnn", "predict", "model", "discrimin", "neural", "featur", "imag", "layer", "train", "stage", "focal", "entropi", "retinanet", "negat", "rapid", "imbal", "background", "candid", "automat", "confid", "penal", "temperatur", "prefer", "ppo", "close", "heurist", "hourglass", "l1", "pix2pix", "fcos", "subnetwork", "subnet", "sac", "foreground", "misclassifi", "proxim", "adamax", "corner", "fake", "trpo", "hard", "exampl", "augment", "varianc", "product", "dot", "polici", "loss", "focus", "factor", "random", "observ", "condit", "key", "actor", "scale", "smooth", "class", "object", "imag", "critic", "valu", "mean", "sampl", "term", "length", "cross", "attent", "stage", "detect", "function", "learn", "use", "train", "optim", "network", "bert", "languag", "recurr", "token", "text", "pair", "left", "downstream", "mlm", "lstm", "sentenc", "vocabulari", "id", "vae", "word2vec", "bay", "unlabel", "autoencod", "gram", "rnns", "favor", "draw", "though", "unidirect", "eschew", "transduct", "domin", "autoregress", "speech", "likelihood", "pre", "bidirect", "fine", "tune", "variat", "transform", "word", "represent", "context", "model", "train", "task", "sequenc", "label", "data", "right", "mask", "decod", "encod", "paramet", "predict", "input", "u ...

# %%
# Topics range
min_topics = 2
max_topics = 20
step_size = 1
topics_range = range(min_topics, max_topics, step_size)
result = list()
for k in topics_range:
  lda_model = LdaMulticore(corpus=corpus,
                           id2word=diccionario,
                           num_topics=k, 
                           random_state=100,
                           chunksize=100,
                           passes=10)
  coherence_model_lda = CoherenceModel(model=lda_model, texts=abstracts.Tokens, dictionary=diccionario, coherence='c_v')
  res = coherence_model_lda.get_coherence()
  result.append(res)

# %%
print(result)
# Out:
# [0.29715152996982236, 0.3808887445143459, 0.3709682479024192, 0.3247190807646821, 0.3990880192621025, 0.3516126182285228, 0.3872212552487986, 0.42506820188965855, 0.3928532989973435, 0.43275224861960626, 0.4537857550396434, 0.4311237241850487, 0.4306931376851689, 0.412582285326902, 0.4198286125965234, 0.4418351003644261, 0.42726308474510744, 0.4159911356810142]

# %%
x = np.arange(2, 20)
plt.plot(x,result)
plt.show()

# %% [markdown]
# We see that the highest coherence score is achieved with 12 topics, therefor we will work on this model and analyze it in relation with the initial labels we had for each abstract.

# %%
lda_model = LdaMulticore(corpus=corpus,
                         id2word=diccionario,
                         num_topics=12, 
                         random_state=100,
                         chunksize=100,
                         passes=10)

# %% [markdown]
# # Analysis with confindence intervals

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                #1 high 2 medium 3 low
                #choices = [1,2,3]
                choices = ['High', 'Medium', 'Low']
                conditions = [prop_topic>=0.66, (prop_topic<0.66) & (prop_topic>=0.33),
                              prop_topic<0.33]
                confidence = np.select(conditions,choices)
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num),
                                                                  round(prop_topic,4),
                                                                  topic_keywords,confidence]),ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords','Confidence']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    labels = abstracts['Label']
    sent_topics_df = pd.concat([sent_topics_df, contents,labels], axis=1)
    return(sent_topics_df)

df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=abstracts['Tokens'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords','Confidence', 'Text','Labels']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.3711
# 1            1             0.0              0.6301
# 2            2             0.0              0.4690
# 3            3             0.0              0.7769
# 4            4             0.0              0.3635
# 5            5             1.0              0.9931
# 6            6             8.0              0.5527
# 7            7             7.0              0.9908
# 8            8             7.0              0.9744
# 9            9            10.0              0.2861
#
#                                             Keywords Confidence  \
# 0  normal, use, weight, batch, adapt, layer, gene...     Medium
# 1  normal, use, weight, batch, adapt, layer, gene...     Medium
# 2  normal, use, weight, batch, adapt, layer, gene...     Medium
# 3  normal, use, weight, batch, adapt, layer, gene...       High
# 4  normal, use, weight, batch, adapt, layer, gene...     Medium
# 5  model, transform, train, pre, bert, languag, r...       High
# 6  featur, spatial, mask, cnn, class, self, roi, ...     Medium
# 7  object, box, network, detect, use, bound, impr...       High
# 8  object, box, network, detect, use, bound, impr...       High
# 9  attent, convolut, featur, scale, product, map,...        Low
#
#                                                 Text  \
# 0  [multipl, random, window, discrimin, multipl, ...
# 1  [dblock, dblock, dblock, residu, base, block, ...
# 2  [gan, tts, gan, tts, gan, tts, generat, advers...
# 3  [condit, dblock, condit, dblock, condit, dbloc...
# 4  [gblock, gblock, gblock, type, residu, block, ...
# 5  [bert, bert, bert, bidirect, encod, represent,...
# 6  [fasttext, fasttext, fasttext, embed, exploit,...
# 7  [faster, cnn, faster, cnn, faster, cnn, object...
# 8  [rpn, region, propos, network, region, propos,...
# 9  [mix, attent, block, mix, attent, block, mix, ...
#
#                         Labels
# 0                      General
# 1                      General
# 2                   Sequential
# 3                      General
# 4                      General
# 5  Natural Language Processing
# 6  Natural Language Processing
# 7              Computer Vision
# 8              Computer Vision
# 9                      General

# %%
for i in range(len(df_dominant_topic)):
  df_dominant_topic.loc[i,'Confidence'] = str(df_dominant_topic.loc[i,'Confidence'])
labels = abstracts['Label'].unique()
for lab in labels:
  df = df_dominant_topic[df_dominant_topic['Labels']==lab]
  sns.histplot(data=df,x='Dominant_Topic', hue="Confidence", 
               multiple="stack", bins=12, hue_order=['High','Medium','Low'])
  plt.title(f'{lab}s dominant topic distribution')
  plt.show()

# %% [markdown]
# Topic 0- Audio (medium low confidence) \\
# Topic 1- NLP (high and medium confidence) \\
# Topic 2- Computer vision (high medium confidence) \\
# Topic 3- \\
# Topic 4- \\
# Topic 5- Graphs (high and medium confidence) \\
# Topic 6- General ? \\
# Topic 7- Computer vision (high confindence) \\
# Topic 8- \\
# Topic 9- Reinforcement learning (high confidence) \\
# Topic 10- Audio (medium confidence), Sequential (high confidence) \\
# Topic 11- \\

# %%
def format_topics_sentences_2(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()
    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        #i = 1 row_list = [(0, 0.27679166), (3, 0.27490905), (6, 0.3157097), (9, 0.102254316)]
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        if len(row) == 1:
          top = row[0][0]
          prop_topic = round(row[0][1],4)
          choices = ['High', 'Medium', 'Low']
          conditions = [prop_topic>=0.66, (prop_topic<0.66) & (prop_topic>=0.33),
                        prop_topic<0.33]
          conf_1 = np.select(conditions,choices)
          sent_topics_df = sent_topics_df.append(pd.Series([top,prop_topic,conf_1,np.nan,np.nan,np.nan]),ignore_index=True)
        else:
          top_1 = row[0][0]
          prop_topic_1 = round(row[0][1],4)
          choices = ['High', 'Medium', 'Low']
          conditions = [prop_topic_1>=0.66, (prop_topic_1<0.66) & (prop_topic_1>=0.33),
                        prop_topic_1<0.33]
          conf_1 = np.select(conditions,choices)
          top_2 = row[1][0]
          prop_topic_2 = round(row[1][1],4)
          choices = ['High', 'Medium', 'Low']
          conditions = [prop_topic_2>=0.66, (prop_topic_2<0.66) & (prop_topic_2>=0.33),
                        prop_topic_2<0.33]
          conf_2 = np.select(conditions,choices)
          sent_topics_df = sent_topics_df.append(pd.Series([top_1,prop_topic_1,conf_1,top_2,prop_topic_2,conf_2]),ignore_index=True)
    # Add original text to the end of the output
    contents = pd.Series(texts)
    labels = abstracts['Label']
    sent_topics_df = pd.concat([sent_topics_df, contents,labels], axis=1)
    return(sent_topics_df)

df_topic_sents_keywords_2 = format_topics_sentences_2(ldamodel=lda_model, corpus=corpus, texts=abstracts['Tokens'])
#df_topic_sents_keywords.head(10)

# %%
# Format
df_dominant_topic_2 = df_topic_sents_keywords_2.reset_index()
df_dominant_topic_2.columns = ['Document_No', 'Dominant_Topic_1', 'Topic_1_Perc_Contrib',
                               'Confidence_1', 'Dominant_Topic_2', 'Topic_2_Perc_Contrib',
                               'Confidence_2','Text','Labels']
df_dominant_topic_2.head(10)
# Out:
#    Document_No  Dominant_Topic_1  Topic_1_Perc_Contrib Confidence_1  \
# 0            0               5.0                0.2596          Low
# 1            1               6.0                0.3122          Low
# 2            2               6.0                0.2393          Low
# 3            3               6.0                0.4441       Medium
# 4            4              10.0                0.2245          Low
# 5            5               1.0                0.9931         High
# 6            6               8.0                0.5231       Medium
# 7            7               7.0                0.9908         High
# 8            8               7.0                0.9901         High
# 9            9              10.0                0.3037          Low
#
#    Dominant_Topic_2  Topic_2_Perc_Contrib Confidence_2  \
# 0               6.0                0.2339          Low
# 1               0.0                0.2807          Low
# 2               5.0                0.2360          Low
# 3               0.0                0.3100          Low
# 4               5.0                0.2104          Low
# 5               NaN                   NaN          NaN
# 6               0.0                0.3853       Medium
# 7               NaN                   NaN          NaN
# 8               NaN                   NaN          NaN
# 9               5.0                0.2773          Low
#
#                                                 Text  \
# 0  [multipl, random, window, discrimin, multipl, ...
# 1  [dblock, dblock, dblock, residu, base, block, ...
# 2  [gan, tts, gan, tts, gan, tts, generat, advers...
# 3  [condit, dblock, condit, dblock, condit, dbloc...
# 4  [gblock, gblock, gblock, type, residu, block, ...
# 5  [bert, bert, bert, bidirect, encod, represent,...
# 6  [fasttext, fasttext, fasttext, embed, exploit,...
# 7  [faster, cnn, faster, cnn, faster, cnn, object...
# 8  [rpn, region, propos, network, region, propos,...
# 9  [mix, attent, block, mix, attent, block, mix, ...
#
#                         Labels
# 0                      General
# 1                      General
# 2                   Sequential
# 3                      General
# 4                      General
# 5  Natural Language Processing
# 6  Natural Language Processing
# 7              Computer Vision
# 8              Computer Vision
# 9                      General

# %%
for i in range(len(df_dominant_topic_2)):
  df_dominant_topic_2.loc[i,'Confidence_1'] = str(df_dominant_topic_2.loc[i,'Confidence_1'])
  df_dominant_topic_2.loc[i,'Confidence_2'] = str(df_dominant_topic_2.loc[i,'Confidence_2'])
labels = abstracts['Label'].unique()
for lab in labels:
  df = df_dominant_topic_2[df_dominant_topic_2['Labels']==lab]
  fig = plt.figure(figsize=(10,5))
  fig.suptitle(f'{lab}s dominant topic distribution')
  gs = gridspec.GridSpec(nrows=1, 
                       ncols=2)
  ax1 = fig.add_subplot(gs[0, 0])
  sns.histplot(data=df,x='Dominant_Topic_1', hue="Confidence_1", 
               multiple="stack", bins=10, hue_order=['High', 'Medium', 'Low'])
  ax2 = fig.add_subplot(gs[0, 1])
  sns.histplot(data=df,x='Dominant_Topic_2', hue="Confidence_2", 
               multiple="stack", bins=10, hue_order=['High', 'Medium', 'Low'])
  plt.show()
